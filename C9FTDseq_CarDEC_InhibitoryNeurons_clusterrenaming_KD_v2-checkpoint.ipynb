# %%
#loading packages
import pandas as pd
import os
import numpy as np
import pickle
import anndata as ad
from copy import deepcopy
from shutil import move
import warnings

#import seaborn as sns
#import matplotlib.pyplot as plt

import scanpy as sc
from anndata import AnnData

# %%
### LOAD IN FILE WITH ALL OF THE CLUSTERS

C9FTDsnRNAseq_InNeurons_clustering = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined')

C9FTDsnRNAseq_5clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_5InNeurons.h5ad', compression = None)
C9FTDsnRNAseq_10clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_10InNeurons.h5ad', compression = None)
C9FTDsnRNAseq_15clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_15InNeurons.h5ad', compression = None)
C9FTDsnRNAseq_20clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_20InNeurons.h5ad', compression = None)
C9FTDsnRNAseq_25clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_25InNeurons.h5ad', compression = None)
#C9FTDsnRNAseq_26clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_26InNeurons.h5ad', compression = None)
#C9FTDsnRNAseq_27clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_27InNeurons.h5ad', compression = None)
#C9FTDsnRNAseq_28clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_28InNeurons.h5ad', compression = None)
#C9FTDsnRNAseq_29clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_29InNeurons.h5ad', compression = None)
C9FTDsnRNAseq_30clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_30InNeurons.h5ad', compression = None)
C9FTDsnRNAseq_35clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_35InNeurons.h5ad', compression = None)
C9FTDsnRNAseq_40clusters = sc.read('/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_40InNeurons.h5ad', compression = None)

# %%
C9FTDsnRNAseq_InNeurons_clustering = pd.read_csv('/Users/kesd1/Desktop/lee lab/snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_40InNeurons_annotationsfor40clusters.csv',header=None,index_col=0)
# Out:
# C:\Users\kesd1\AppData\Local\Temp\ipykernel_15300\4057724695.py:1: DtypeWarning: Columns (6,10,11,14,15,16,17,20,21,22,23,24,25,26,27,28,33,34,35,36,37,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   C9FTDsnRNAseq_InNeurons_clustering = pd.read_csv('/Users/kesd1/Desktop/lee lab/snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_40InNeurons_annotationsfor40clusters.csv',header=None,index_col=0)

# %%
C9FTDsnRNAseq_InNeurons_clustering
# Out:
#                                   1        2       3                  4   \
# 0
# newindex                    sampleID   sample   group  ClinicalDiagnosis
# AAACCCATCGACCTAA-1-C9ALS1a   C9ALS1a   C9ALS1  C9-ALS             C9-ALS
# AAACGAATCGCAAGAG-1-C9ALS1a   C9ALS1a   C9ALS1  C9-ALS             C9-ALS
# AAACGCTAGACGCCAA-1-C9ALS1a   C9ALS1a   C9ALS1  C9-ALS             C9-ALS
# AAACGCTCAGTCCCGA-1-C9ALS1a   C9ALS1a   C9ALS1  C9-ALS             C9-ALS
# ...                              ...      ...     ...                ...
# TTGTGGAAGCCTCCAG-1-C9FTD4F   C9FTD4F  C9FTD4F  C9-FTD           C9-bvFTD
# TTGTGGAGTTATGACC-1-C9FTD4F   C9FTD4F  C9FTD4F  C9-FTD           C9-bvFTD
# TTGTTGTTCTCTGGTC-1-C9FTD4F   C9FTD4F  C9FTD4F  C9-FTD           C9-bvFTD
# TTTACGTGTGTTGCCG-1-C9FTD4F   C9FTD4F  C9FTD4F  C9-FTD           C9-bvFTD
# TTTGATCTCCTAGCGG-1-C9FTD4F   C9FTD4F  C9FTD4F  C9-FTD           C9-bvFTD
#
#                                            5           6           7       8   \
# 0
# ...

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('0','CHRM2+LGR5+LHX6+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('1','TYR+GGH+CCDC184+ADARB2+VIP+CBLN1+CASC6+LGR5+CHRM2+HS3ST3A1+CHRNA4+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('2','LAMP5+ADARB2+TNFAIP8L3+CDH12+NMBR+LCP2+CHRNA4+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('3','TNFAIP8L3+LAMP5+CA1+ADARB2+CPRM1+NPY+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('4','SCUBE3+LHX6+B3GAT2+CDH12+')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('0','CHRM2+LGR5+LHX6+CDH12+')
#       2 C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('1','TYR+GGH+CCDC184+ADARB2+VIP+CBLN1+CASC6+LGR5+CHRM2+HS3ST3A1+CHRNA4+')
#       3 C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_5clusters'].replace('2','LAMP5+ADARB2+TNFAIP8L3+CDH12+NMBR+LCP2+CHRNA4+')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
# ...

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('0','CDH12+CHRM2+LBH+LHX6+LGR5+MEPE+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('1','CDH12+ADARB2+VIP+HS3ST3A1+TYR+CHRM2+CBLN1+CCDC184+GGH+CASC6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('2','LGR5+LHX6+STK32A+CALB1+ADGRG6+GXYLT2+B3GAT2+HPGD+OPRM1+CHRM2+ADAMTSL1+SST+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('3','CDH12+TNFAIP8L3+NMBR+CHRNA4+ADARB2+ADAMTSL1+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('4','CDH12+CHRM2+SPAG17+LHX6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('5','PAX6+CDH12+TNFAIP8L3+CHRNA4+ADARB2+SYT6+CHRNA6+CHRM2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('6','TNFAIP8L3+LAMP5+LCP2+ADARB2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('7','SULF1+LHX6+CALB1+ADGRG6+OPRM1+ADARB2+CA1+LAMP5+TNFAIP8L3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('8','CDH12+SPAG17+CALB1+LHX6+SCUBE3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_10clusters'].replace('9','SULF1+LHX6+NPY+CHRM2+ADAMTSL1+SST+ADARB2+CDH12+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('0','CDH12+LHX6+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('1','LGR5+MEPE+WFDC2+SULF1+LHX6+CHRM2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('2','CDH12+ADARB2+VIP+HS3ST3A1+GGH+CHRM2+CBLN1+CCDC184+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('3','LHX6+CALB1+ADGRG6+FRZB+GXYLT2+HPGD+CHRM2+ADAMTSL1+PENK+SST+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('4','SST+CHRM2+OPRM1+GXYLT2+B3GAT2+HPGD+STK32A+ADGRG6+LHX6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('5','LGR5+CASC6+SPAG17+OPRM1+CCDC184+CBLN1+CHRM2+HS3STSA1+CHRNA6+VIP+CLP2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('6','TNFAIP8L3+LAMP5+LCP2+ADARB2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('7','HPGD+CHRNA6+MC4R+ADARB2+CHRNA4+NMBR+CDH12+TNFAIP8L3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('8','ADARB2+VIP+ADAMTSL1+PENK+TYR+GGH+CASC6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('9','LHX6+CALB1+ADGRG6+OPRM1+ADARB2+CA1+LAMP5+TNFAIP8L3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('10','PAX6+CDH12+TNFAIP8L3+CHRNA4+ADARB2+TSPAN12+SYT6+CHRNA6+CHRM2+GXYLT2+B2GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('11','SCUBE3+LHX6+CALB1+B3GAT2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('12','CHRM2+SPAG17+HPGD+LHX6+GLP1R+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('13','ADAMTSL1+CDH12+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_15clusters'].replace('14','LHX6+GXYLT2+B3GAT2+CHRM2+PENK+CDH12+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('0','CDH12+LHX6+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('1','CDH12+SST+OPRM1+B3GAT2+GXYLT2+ADGRG6+STK32A+LHX6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('2','B3GAT2+ADARB2+LCP2+TNFAIP8L3+LAMP5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('3','CDH12+NMBR+CHRNA4+ADARB2+MC4R+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('4','CASC6+GGH+CBLN1+HS3ST3A1+TYR+VIP+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('5','CDH12+LHX6+LGR5+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('6','WFDC2+LHX6+CALB1+FRZB+HPGD+PENK+ADAMTSL1+MC4R+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('7','CDH12+ADARB2+CHRM2+CBLN1+CCDC184+GGH+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('8','LHX6+CALB1+ADGRG6+OPRM1+ADARB2+CA1+TNFAIP8L3+LAMP5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('9','ADARB2+VIP+ADAMTSL1+PENK+TYR+GGH+CASC6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('10','LGR5+CASC6+SPAG17+OPRM1+CBLN1+CCDC184+CHRNA6+VIP+ADARB2+LCP2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('11','CDH12+B3GAT2+CALB1+LHX6+SCUBE3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('12','LHX6+HPGD+B3GAT2+OPRM1+SST+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('13','CDH12+LBH+LHX6+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('14','LGR5+LHX6+HPGD+CHRM2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('15','PAX6+CDH12+TNFAIP8L3+ADARB2+SYT6+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('16','LHX6+ADARB2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('17','ADAMTSL1+CHRM2+LHX6+LGR5+MEPE+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('18','LHX6+B3GAT2+GXYLT2+PENK+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_20clusters'].replace('19','PAX6+CDH12+TNFAIP8L3+CHRNA4+ADARB2+TSPAN12+CHRM2+B3GAT2+GXYLT2+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('0','CDH12+LHX6+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('1','CHRM2+LHX6+SULF1+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('2','TNFAIP8L3+LAMP5+LCP2+ADARB2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('3','TNFAIP8L3+LAMP5+CA1+ADARB2+OPRM1+CALB1+ADGRG6+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('4','CDH12+ADAMTSL1+PENK+FRZB+CALB1+LHX6+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('5','CDH12+ADARB2+CHRM2+CCDC184+GGH+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('6','CHD12+SST+CHRM2+OPRM1+GXYLT2+ADGRG6+CALB1+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('7','PAX6+LCP2+ADARB2+VIP+CHRNA6+CCDC184+CASC6+SPAG17+OPRM1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('8','CDH12+B3GAT1+CALB1+LHX6+SCUBE3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('9','CDH12+ADARB2+VIP+HS3ST3A1+GGH+CBLN1+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('10','CDH12+TNFAIP8L3+CHRNA4+ADARB2+MC4R+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('11','CDH12+SST+CHRM2+OPRM1+B3GAT2+HPGD+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('12','LGR5+LHX6+STK32A+ADGRG6+GXYLT2+B3GAT2+OPRM1+SST+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('13','CDH12+DBP+LBH+LHX6+PVALB+SULF1+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('14','ADARB2+VIP+HS3ST3A1+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('15','CHD12+CHRM2+SPAG17+LHX6+GLP1R+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('16','ADARB2+VIP+CHRNA6+TYR+CCDC184+GGH+CASC6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('17','LAMP5+NMBR+CHRNA4+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('18','CASC6+GGH+PENK+ADAMTSL1+VIP+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('19','PAX6+TNFAIP8L3+CHRNA4+ADARB2+VIP+SYT6+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('20','LHX6+GXYLT2+B3GAT2+CHRM2+PENK+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('21','PAX6+CDH12+TNFAIP8L3+CHRNA4+ADARB2+CHRM2+GXYLT2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('22','CDH12+ADARB2+ADAMTSL1+OPRM1+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('23','LHX6+ADGRG6+NPY+OPRM1+CHRM2+PENK+ADAMTSL1+SST+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_25clusters'].replace('24','CDH12+ADARB2+CHRNA6+GXYLT2+LGR5+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('0','CDH12+CHRM2+LBH+LHX6+SULF1+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('1','CDH12+LBH+LHX6+SULF1+WFDC2+_1')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('2','TNFAIP8L3+LAMP5+LCP2+ADARB2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('3','LHX6+ADGRG6+OPRM1+ADARB2+CA1+LAMP5+TNFAIP8L3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('4','CDH12+SST+CHRM2+OPRM1+GXYLT2+ADGRG6+LHX6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('5','SCUBE3+LHX6+B3GAT2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('6','CDH12+ADARB2+VIP+GGH+CCDC184+CBLN1+CHRM2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('7','CDH12+TNFAIP8L3+CHRNA4+ADARB2+MC4R+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('8','CASC6+GGH+CBLN1+HS3ST3A1+VIP+ADARB2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('9','PAX6+LCP2+ADARB2+VIP+CHRNA6+CBLN1+CCDC184+CASC6+SPAG17+OPRM1+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('10','CDH12+SST+ADAMTSL1+PENK+FRZB+CALB1+LHX6+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('11','SST+OPRM1+GXYLT2+B3GAT2+STK32A+ADGRG6+LHX6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('12','CDH12+LBH+LHX6+SULF1+WFDC2+_2')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('13','CDH12+CCDC184+LBH+LHX6+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('14','ADARB2+VIP+HS3ST3A1+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('15','CDH12+LHX6+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('16','CDH12+SST+CHRM2+OPRM1+HPGD+B3GAT2+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('17','LAMP5+NMBR+CHRNA4+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('18','ADARB2+VIP+CHRNA6+TYR+GGH+CBLN1+CASC6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('19','CHRNA6+ADARB2+VIP+PENK+ADAMTSL1+GGH+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('20','CHRNA6+VIP+ADARB2+PAX6+TNFAIP8L3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('21','CHRM2+SPAG17+LHX6+GLP1R+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('22','LHX6+GXYLT2+CHRM2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('23','PAX6+CDH12+TNFAIP8L3+CHRNA4+ADARB2+CHRM2+B3GAT2+GXYLT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('24','LHX6+TH+SST+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('25','TNFAIP8L3+ADARB2+CHRNA4+CHRNA6+CASC6+HPGD+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('26','CDH12+ADARB2+ADAMTSL1+OPRM1+LHX6+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('27','CDH12+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('28','TNFAIP8L3+LAMP5+LCP2+ADARB2+LCP2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_30clusters'].replace('29','CDH12+SST+ADAMTSL1+PENK+CHRM2+OPRM1+NPY+ADGRG6+LHX6+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('0','CDH12+CHRM2+LBH+LHX6+SULF1+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('1','TNFAIP8L3+LAMP5+LCP2+ADARB2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('2','CDH12+LHX6+SULF1+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('3','TNFAIP8L3+LAMP5+CA1+ADARB2+OPRM1+CALB1+ADGRG6+LHX6+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('4','CDH12+SST+CHRM2+OPRM1+GXYLT2+CALB1+ADGRG6+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('5','CDH12+LBH+LHX6+SULF1+WFDC2+_3')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('6','CDH12+B3GAT2+CALB1+LHX6+SCUBE3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('7','CASC6+GGH+CBLN1+HS3ST3A1+VIP+ADARB2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('8','CDH12+ADARB2+VIP+CRHM2+CBLN1+CCDC184+GGH+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('9','CDH12+SST+ADAMTSL1+PENK+HPGD+CALB1+FRZB+LHX6+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('10','CDH12+LBH+LHX6+WFDC2+SULF1+_1')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('11','PAX6+LCP2+ADARB2+VIP+CHRNA6+QPCT+CCDC184+CBLN1+CHRM2+CASC6+SPAG17+OPRM1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('12','SST+OPRM1+B3GAT2+GXYLT2+STK32A+ADGRG6+LHX6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('13','ADARB2+VIP+HS3ST3A1+CBLN1+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('14','CDH12+SST+CHRM2+OPRM1+HPGD+B3GAT2+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('15','LAMP5+NMBR+ADARB2+SERPINF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('16','CDH12+TNFAIP8L3+ADARB2+SYT6+ADAMTSL1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('17','CHRM2+SPAG17+LHX6+GLP1R+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('18','CDH12+LBH+LHX6+WFDC2+SULF1+_2')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('19','PAX6+TNFAIP8L3+CHRNA4+ADARB2+TSAN12+SYT6+VIP+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('20','LHX6+GXYLT2+CHRM2+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('21','ADARB2+VIP+PENK+ADAMTSL1+GGH+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('22','ADARB2+VIP+CHRNA6+TYR+GGH+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('23','CDH12+FRZB+CALB1+LHX6+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('24','CDH12+TNFAIP8L3+CHRNA4+ADARB2+MC4R+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('25','PAX6+CHD12+TNFAIP8L3+CHRNA4+ADARB2+TSPAN12+CHRM2+B3GAT2+GXYLT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('26','LGR5+CASC6+GGH+CCDC184+CBLN1+SERPINF1+CHRNA6+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('27','ADARB2+CHRNA6+CASC6+HPGD+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('28','LHX6+TH+SST+CDH12+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('29','CDH12+ADARB2+ADAMTSL1+LHX6+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('30','ADARB2+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('31','CDH12+DBP+QPCT+CHRM2+OPRM1+GXYLT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('32','TNFAIP8L3+LAMP5+DBP+LCP2+ADARB2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('33','TNFAIP8L3+LAMP5+CA1+ADARB2+OPRM1+CALB1+ADGRG6+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_35clusters'].replace('34','CDH12+SST+PENK+CHRM2+NPY+LHX6+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('0','TNFAIP8L3+LAMP5+LCP2+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('1','CHRM2+LHX6+WFDC2+SULF1+_1')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('2','CDH12+LHX6+WFDC2+SULF+_1')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('3','CDH12+SST+CHRM2+OPRM1+GXYLT2+CALB1+ADGRG6+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('4','TNFAIP8L3+LAMP5+CA1+ADARB2+OPRM1+CALB1+ADGRG6+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('5','CDH12+ADARB2+VIP+HS3ST3A1+CBLN1+GGH+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('6','CDH12+ADARB2+VIP+GGH+CCDC184+CBLN1+CHRM2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('7','CDH12+LBH+LHX6+WFDC2+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('8','PAX6+LCP2+ADARB2+VIP+QPCT+CHRNA6+CCDC184+CBLN1+CASC6+SPAG17+OPRM1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('9','CDH12+B3GAT2+CALB1+LHX6+SCUBE3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('10','CDH12+SST+ADANTSL1+PENK+HPGD+FRZB+CALB1+LHX6+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('11','CDH12+FRZB+CALB1+LHX6+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('12','CDH12+DBP+CCDC184+LBH+LHX6+PVALB+SULF1+WFDC2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('13','SST+OPRM1+GXYLT2+B3GAT2+STK32A+ADGRG6+LHX6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('14','ADARB2+VIP+HS3ST3A1+CBLN1+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('15','CDH12+SST+CHRM2+OPRM1+HPGD+B3GAT2+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('16','CHRM2+SPAG17+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('17','LAMP5+NMBR+ADARB2+CHRNA4+SERFINF1+PCDH20+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('18','CDH12+TNFAIP8L3+CHRNA1+ADARB2+SYT6+ADAMTSL1+SERPINF+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('19','CDH12+CHRM2+GXYLT2+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('20','ADARB2+VIP+ADAMTSL1+PENK+GGH+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('21','ADARB2+VIP+CHRNA6+TYR+PCDH20+GGH+CASC6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('22','CDH12+LHX6+WFDC2+SULF1+_2')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('23','CDH12+LHX6+WFDC2+SULF1+_3')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('24','CDH12+TNFAIP8L3+CHRNA4+ADARB2+MC4R+CHRNA6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('25','ADARB2+CHRNA6+SERPINF1+CBLN1+CCDC184+GGH+CASC6+LGR5+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('26','CHRM2+LHX6+WFDC2+SULF1+_2')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('27','ADARB2+CHRNA6+CCDC184+CASC6+HPGD+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('28','CDH12+ADARB2+OPRM1+LHX6+SULF1+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('29','CDH12+TNFAIP8L3+CHRNA4+ADARB2+TSPAN12+SYT6+CHRNA6+HPGD+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('30','CDH12+SST+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('31','PAX6+TNFAIP8L3+ADARB2+TSPAN12+SYT6+VIP+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('32','LAMP5+TNFAIP8L3+DBP+ADARB2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('33','TNFAIP8L3+LAMP5+CA1+ADARB2+OPRM1+CALB1+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('34','TNFAIP8L3+LAMP5+DBP+LCP2+ADARB2+B3GAT2+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('35','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('36','CDH12+DBP+PCDH20+B3GAT2+LHX6+CALB1+SCUBE3+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('37','DBP+SST+QPCT+OPRM1+GXYLT2+B3GAT2+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('38','ADARB2+LHX6+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_40clusters'].replace('39','')

# %%
C9FTDsnRNAseq_InNeurons_clustering.write("/Drive-1/daviddai/David/C9orf72/C9FTDvsCtrl_snRNAseq/C9FTDsnRNAseqrefined_clustering_45clusters_40InNeurons_annotationnames.h5ad", compression = None)

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('0','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('1','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('2','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('3','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('4','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('5','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('6','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('7','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('8','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('9','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('10','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('11','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('12','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('13','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('14','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('15','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('16','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('17','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('18','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('19','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('20','')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('21','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('22','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('23','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('24','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_26clusters'].replace('25','+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('0','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('1','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('2','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('3','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('4','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('5','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('6','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('7','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('8','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('9','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('10','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('11','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('12','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('13','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('14','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('15','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('16','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('17','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('18','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('19','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('20','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('21','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('22','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('23','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('24','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('25','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_27clusters'].replace('26','+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('0','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('1','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('2','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('3','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('4','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('5','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('6','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('7','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('8','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('9','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('10','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('11','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('12','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('13','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('14','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('15','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('16','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('17','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('18','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('19','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('20','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('21','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('22','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('23','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('24','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('25','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('26','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_28clusters'].replace('27','+')

# %%
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('0','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('1','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('2','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('3','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('4','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('5','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('6','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('7','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('8','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('9','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('10','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('11','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('12','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('13','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('14','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('15','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('16','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('17','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('18','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('19','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('20','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('21','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('22','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('23','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('24','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('25','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('26','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('27','+')
C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'] = C9FTDsnRNAseq_InNeurons_clustering.obs['InNeuron_29clusters'].replace('28','+')
