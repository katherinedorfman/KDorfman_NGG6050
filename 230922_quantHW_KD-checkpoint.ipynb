# %% [markdown]
# link to chat GPT conversation used for this analysis: https://chat.openai.com/c/1ce69722-adf0-4efd-9141-0db1a20214d0

# %%
# simulate multiple (say, 1000) t-tests comparing two samples with equal means and standard deviations, and save the p-values

import numpy as np
from scipy.stats import ttest_ind

# Parameters
sample_size = 100  # Size of each sample
num_simulations = 1000  # Number of simulations
mean = 1 # mean of both samples is 1

# Initialize an empty list to store p-values
p_values = []

# Simulate t-tests
for _ in range(num_simulations):
    # Generate two random samples with equal means and standard deviations
    sample1 = np.random.normal(loc=mean, scale=1, size=sample_size)
    sample2 = np.random.normal(loc=mean, scale=1, size=sample_size)
    
    # Perform a t-test
    _, p_value = ttest_ind(sample1, sample2)
    
    # Append the p-value to the list
    p_values.append(p_value)


p_values_lessthan05_count = sum(i < 0.05 for i in p_values)
p_values_lessthan05_proportion = p_values_lessthan05_count / num_simulations
print(f"Proportion of p-values less than 0.05: {p_values_lessthan05_proportion:.3f}")
# Out:
# Proportion of p-values less than 0.05: 0.045

# %% [markdown]
# Benjamini-Hochberg procedure
#
# 1. Rank the individual p-values in ascending order, labeled i=1...n
#
# 2. For each p-value, calculate its "critical value" as (i/n)Q, where i is the rank, n is the total number of tests, and Q is the false discovery rate (a percentage) that you choose (typically 0.05).
#
# 3. In your rank-ordered, original p-values, find the largest value that is smaller than its associated critical value; this p-value is the new criterion (i.e., reject for all cases for which p ≤ this value).

# %%
# use the Benjamini-Hochberg procedure to address the multiple comparisons problem

# STEP 1: Rank the individual p-values in ascending order, labeled i=1...n

# Rank the p-values in ascending order and assign labels as numbers
sorted_indices = np.argsort(p_values)  # Indices that would sort the p-values

# Create a dictionary to map ranks to p-values
ranked_p_values = {str(i): p_values[idx] for i, idx in enumerate(sorted_indices, start=1)}


# STEP 2: For each p-value, calculate its "critical value" as (i/n)Q, where i is the rank, n is the total number of tests, and Q is the false discovery rate (a percentage) that you choose (typically 0.05).

false_discovery_rate = 0.05
critical_values = [(i / num_simulations) * false_discovery_rate for i in range(1, num_simulations + 1)]

# Print the ranked p-values and their corresponding critical values
for rank, (p_value, critical_value) in enumerate(zip(np.array(p_values)[sorted_indices], critical_values), start=1):
    print(f"Rank {rank}: P-Value = {p_value:.3f}, Critical Value = {critical_value:.3f}")
    
# STEP 3: In your rank-ordered, original p-values, find the largest value that is smaller than its associated critical value; this p-value is the new criterion (i.e., reject for all cases for which p ≤ this value).

# Find the largest p-value that is smaller than its associated critical value
new_criterion = None
for p_value, critical_value in zip(np.array(p_values)[sorted_indices], critical_values):
    if p_value <= critical_value:
        new_criterion = p_value
    else:
        break
        
# Print the new criterion
print(f"New Criterion: P-Value <= {new_criterion}")
# Out:
# Rank 1: P-Value = 0.003, Critical Value = 0.000
# Rank 2: P-Value = 0.004, Critical Value = 0.000
# Rank 3: P-Value = 0.007, Critical Value = 0.000
# Rank 4: P-Value = 0.008, Critical Value = 0.000
# Rank 5: P-Value = 0.011, Critical Value = 0.000
# Rank 6: P-Value = 0.011, Critical Value = 0.000
# Rank 7: P-Value = 0.012, Critical Value = 0.000
# Rank 8: P-Value = 0.012, Critical Value = 0.000
# Rank 9: P-Value = 0.013, Critical Value = 0.000
# Rank 10: P-Value = 0.014, Critical Value = 0.001
# Rank 11: P-Value = 0.015, Critical Value = 0.001
# Rank 12: P-Value = 0.015, Critical Value = 0.001
# Rank 13: P-Value = 0.016, Critical Value = 0.001
# Rank 14: P-Value = 0.017, Critical Value = 0.001
# Rank 15: P-Value = 0.018, Critical Value = 0.001
# Rank 16: P-Value = 0.018, Critical Value = 0.001
# Rank 17: P-Value = 0.020, Critical Value = 0.001
# Rank 18: P-Value = 0.020, Critical Value = 0.001
# Rank 19: P-Value = 0.021, Critical Value = 0.001
# Rank 20: P-Value = 0.021, Critical Value = 0.001
# Rank 21: P-Value = 0.025, Critical Value = 0.001
# Rank 22: P-Value = 0.028, Critical Value = 0.001
# Rank 23: P-Value = 0.029, Critical Value = 0.001
# Rank 24: P-Value = 0.030, Critical Value = 0.001
# Rank 25: P-Value = 0.030, Critical Value = 0.001
# Rank 26: P-Value = 0.030, Critical Value = 0.001
# Rank 27: P-Value = 0.031, Critical Value = 0.001
# Rank 28: P-Value = 0.034, Critical Value = 0.001
# Rank 29: P-Value = 0.035, Critical Value = 0.001
# Rank 30: P-Value = 0.035, Critical Value = 0.002
# Rank 31: P-Value = 0.036, Critical Value = 0.002
# Rank 32: P-Value = 0.037, Critical Value = 0.002
# Rank 33: P-Value = 0.038, Critical Value = 0.002
# Rank 34: P-Value = 0.038, Critical Value = 0.002
# Rank 35: P-Value = 0.041, Critical Value = 0.002
# Rank 36: P-Value = 0.042, Critical Value = 0.002
# Rank 37: P-Value = 0.042, Critical Value = 0.002
# Rank 38: P-Value = 0.045, Critical Value = 0.002
# Rank 39: P-Value = 0.045, Critical Value = 0.002
# Rank 40: P-Value = 0.045, Critical Value = 0.002
# Rank 41: P-Value = 0.047, Critical Value = 0.002
# Rank 42: P-Value = 0.048, Critical Value = 0.002
# Rank 43: P-Value = 0.048, Critical Value = 0.002
# Rank 44: P-Value = 0.049, Critical Value = 0.002
# Rank 45: P-Value = 0.049, Critical Value = 0.002
# Rank 46: P-Value = 0.051, Critical Value = 0.002
# Rank 47: P-Value = 0.051, Critical Value = 0.002
# Rank 48: P-Value = 0.053, Critical Value = 0.002
# Rank 49: P-Value = 0.055, Critical Value = 0.002
# Rank 50: P-Value = 0.056, Critical Value = 0.003
# Rank 51: P-Value = 0.056, Critical Value = 0.003
# Rank 52: P-Value = 0.057, Critical Value = 0.003
# Rank 53: P-Value = 0.058, Critical Value = 0.003
# Rank 54: P-Value = 0.058, Critical Value = 0.003
# Rank 55: P-Value = 0.059, Critical Value = 0.003
# Rank 56: P-Value = 0.060, Critical Value = 0.003
# Rank 57: P-Value = 0.061, Critical Value = 0.003
# Rank 58: P-Value = 0.061, Critical Value = 0.003
# Rank 59: P-Value = 0.061, Critical Value = 0.003
# Rank 60: P-Value = 0.062, Critical Value = 0.003
# Rank 61: P-Value = 0.063, Critical Value = 0.003
# Rank 62: P-Value = 0.064, Critical Value = 0.003
# Rank 63: P-Value = 0.065, Critical Value = 0.003
# Rank 64: P-Value = 0.068, Critical Value = 0.003
# Rank 65: P-Value = 0.071, Critical Value = 0.003
# Rank 66: P-Value = 0.072, Critical Value = 0.003
# Rank 67: P-Value = 0.072, Critical Value = 0.003
# Rank 68: P-Value = 0.072, Critical Value = 0.003
# Rank 69: P-Value = 0.073, Critical Value = 0.003
# Rank 70: P-Value = 0.074, Critical Value = 0.004
# Rank 71: P-Value = 0.075, Critical Value = 0.004
# Rank 72: P-Value = 0.075, Critical Value = 0.004
# Rank 73: P-Value = 0.077, Critical Value = 0.004
# Rank 74: P-Value = 0.078, Critical Value = 0.004
# Rank 75: P-Value = 0.078, Critical Value = 0.004
# Rank 76: P-Value = 0.082, Critical Value = 0.004
# Rank 77: P-Value = 0.082, Critical Value = 0.004
# Rank 78: P-Value = 0.083, Critical Value = 0.004
# Rank 79: P-Value = 0.086, Critical Value = 0.004
# Rank 80: P-Value = 0.088, Critical Value = 0.004
# Rank 81: P-Value = 0.089, Critical Value = 0.004
# Rank 82: P-Value = 0.090, Critical Value = 0.004
# Rank 83: P-Value = 0.092, Critical Value = 0.004
# Rank 84: P-Value = 0.092, Critical Value = 0.004
# Rank 85: P-Value = 0.094, Critical Value = 0.004
# Rank 86: P-Value = 0.094, Critical Value = 0.004
# Rank 87: P-Value = 0.095, Critical Value = 0.004
# Rank 88: P-Value = 0.095, Critical Value = 0.004
# Rank 89: P-Value = 0.097, Critical Value = 0.004
# Rank 90: P-Value = 0.097, Critical Value = 0.004
# Rank 91: P-Value = 0.098, Critical Value = 0.005
# Rank 92: P-Value = 0.099, Critical Value = 0.005
# Rank 93: P-Value = 0.099, Critical Value = 0.005
# Rank 94: P-Value = 0.100, Critical Value = 0.005
# Rank 95: P-Value = 0.101, Critical Value = 0.005
# Rank 96: P-Value = 0.101, Critical Value = 0.005
# Rank 97: P-Value = 0.101, Critical Value = 0.005
# Rank 98: P-Value = 0.102, Critical Value = 0.005
# Rank 99: P-Value = 0.103, Critical Value = 0.005
# Rank 100: P-Value = 0.104, Critical Value = 0.005
# Rank 101: P-Value = 0.104, Critical Value = 0.005
# Rank 102: P-Value = 0.105, Critical Value = 0.005
# Rank 103: P-Value = 0.105, Critical Value = 0.005
# Rank 104: P-Value = 0.108, Critical Value = 0.005
# Rank 105: P-Value = 0.108, Critical Value = 0.005
# Rank 106: P-Value = 0.112, Critical Value = 0.005
# Rank 107: P-Value = 0.113, Critical Value = 0.005
# Rank 108: P-Value = 0.115, Critical Value = 0.005
# Rank 109: P-Value = 0.116, Critical Value = 0.005
# Rank 110: P-Value = 0.118, Critical Value = 0.006
# Rank 111: P-Value = 0.118, Critical Value = 0.006
# Rank 112: P-Value = 0.118, Critical Value = 0.006
# Rank 113: P-Value = 0.118, Critical Value = 0.006
# Rank 114: P-Value = 0.120, Critical Value = 0.006
# Rank 115: P-Value = 0.121, Critical Value = 0.006
# Rank 116: P-Value = 0.123, Critical Value = 0.006
# Rank 117: P-Value = 0.123, Critical Value = 0.006
# Rank 118: P-Value = 0.126, Critical Value = 0.006
# Rank 119: P-Value = 0.127, Critical Value = 0.006
# Rank 120: P-Value = 0.127, Critical Value = 0.006
# Rank 121: P-Value = 0.127, Critical Value = 0.006
# Rank 122: P-Value = 0.128, Critical Value = 0.006
# Rank 123: P-Value = 0.128, Critical Value = 0.006
# Rank 124: P-Value = 0.128, Critical Value = 0.006
# Rank 125: P-Value = 0.131, Critical Value = 0.006
# Rank 126: P-Value = 0.131, Critical Value = 0.006
# Rank 127: P-Value = 0.132, Critical Value = 0.006
# Rank 128: P-Value = 0.132, Critical Value = 0.006
# Rank 129: P-Value = 0.132, Critical Value = 0.006
# Rank 130: P-Value = 0.132, Critical Value = 0.007
# Rank 131: P-Value = 0.133, Critical Value = 0.007
# Rank 132: P-Value = 0.136, Critical Value = 0.007
# Rank 133: P-Value = 0.138, Critical Value = 0.007
# Rank 134: P-Value = 0.139, Critical Value = 0.007
# Rank 135: P-Value = 0.140, Critical Value = 0.007
# Rank 136: P-Value = 0.140, Critical Value = 0.007
# Rank 137: P-Value = 0.142, Critical Value = 0.007
# Rank 138: P-Value = 0.143, Critical Value = 0.007
# Rank 139: P-Value = 0.143, Critical Value = 0.007
# Rank 140: P-Value = 0.145, Critical Value = 0.007
# Rank 141: P-Value = 0.145, Critical Value = 0.007
# Rank 142: P-Value = 0.147, Critical Value = 0.007
# Rank 143: P-Value = 0.149, Critical Value = 0.007
# Rank 144: P-Value = 0.149, Critical Value = 0.007
# Rank 145: P-Value = 0.149, Critical Value = 0.007
# Rank 146: P-Value = 0.150, Critical Value = 0.007
# Rank 147: P-Value = 0.150, Critical Value = 0.007
# Rank 148: P-Value = 0.155, Critical Value = 0.007
# Rank 149: P-Value = 0.156, Critical Value = 0.007
# Rank 150: P-Value = 0.156, Critical Value = 0.007
# Rank 151: P-Value = 0.157, Critical Value = 0.008
# Rank 152: P-Value = 0.162, Critical Value = 0.008
# Rank 153: P-Value = 0.162, Critical Value = 0.008
# Rank 154: P-Value = 0.164, Critical Value = 0.008
# Rank 155: P-Value = 0.164, Critical Value = 0.008
# Rank 156: P-Value = 0.165, Critical Value = 0.008
# Rank 157: P-Value = 0.167, Critical Value = 0.008
# Rank 158: P-Value = 0.168, Critical Value = 0.008
# Rank 159: P-Value = 0.168, Critical Value = 0.008
# Rank 160: P-Value = 0.168, Critical Value = 0.008
# Rank 161: P-Value = 0.168, Critical Value = 0.008
# Rank 162: P-Value = 0.169, Critical Value = 0.008
# Rank 163: P-Value = 0.169, Critical Value = 0.008
# Rank 164: P-Value = 0.169, Critical Value = 0.008
# Rank 165: P-Value = 0.170, Critical Value = 0.008
# Rank 166: P-Value = 0.173, Critical Value = 0.008
# Rank 167: P-Value = 0.174, Critical Value = 0.008
# Rank 168: P-Value = 0.174, Critical Value = 0.008
# Rank 169: P-Value = 0.175, Critical Value = 0.008
# Rank 170: P-Value = 0.177, Critical Value = 0.009
# Rank 171: P-Value = 0.179, Critical Value = 0.009
# Rank 172: P-Value = 0.180, Critical Value = 0.009
# Rank 173: P-Value = 0.181, Critical Value = 0.009
# Rank 174: P-Value = 0.181, Critical Value = 0.009
# Rank 175: P-Value = 0.183, Critical Value = 0.009
# Rank 176: P-Value = 0.187, Critical Value = 0.009
# Rank 177: P-Value = 0.187, Critical Value = 0.009
# Rank 178: P-Value = 0.190, Critical Value = 0.009
# Rank 179: P-Value = 0.190, Critical Value = 0.009
# Rank 180: P-Value = 0.191, Critical Value = 0.009
# Rank 181: P-Value = 0.192, Critical Value = 0.009
# Rank 182: P-Value = 0.193, Critical Value = 0.009
# Rank 183: P-Value = 0.194, Critical Value = 0.009
# Rank 184: P-Value = 0.195, Critical Value = 0.009
# Rank 185: P-Value = 0.196, Critical Value = 0.009
# Rank 186: P-Value = 0.197, Critical Value = 0.009
# Rank 187: P-Value = 0.199, Critical Value = 0.009
# Rank 188: P-Value = 0.199, Critical Value = 0.009
# Rank 189: P-Value = 0.199, Critical Value = 0.009
# Rank 190: P-Value = 0.201, Critical Value = 0.010
# Rank 191: P-Value = 0.202, Critical Value = 0.010
# Rank 192: P-Value = 0.202, Critical Value = 0.010
# Rank 193: P-Value = 0.203, Critical Value = 0.010
# Rank 194: P-Value = 0.203, Critical Value = 0.010
# Rank 195: P-Value = 0.204, Critical Value = 0.010
# Rank 196: P-Value = 0.204, Critical Value = 0.010
# Rank 197: P-Value = 0.205, Critical Value = 0.010
# Rank 198: P-Value = 0.207, Critical Value = 0.010
# Rank 199: P-Value = 0.208, Critical Value = 0.010
# Rank 200: P-Value = 0.209, Critical Value = 0.010
# Rank 201: P-Value = 0.211, Critical Value = 0.010
# Rank 202: P-Value = 0.212, Critical Value = 0.010
# Rank 203: P-Value = 0.213, Critical Value = 0.010
# Rank 204: P-Value = 0.213, Critical Value = 0.010
# Rank 205: P-Value = 0.213, Critical Value = 0.010
# Rank 206: P-Value = 0.216, Critical Value = 0.010
# Rank 207: P-Value = 0.217, Critical Value = 0.010
# Rank 208: P-Value = 0.218, Critical Value = 0.010
# Rank 209: P-Value = 0.219, Critical Value = 0.010
# Rank 210: P-Value = 0.219, Critical Value = 0.011
# Rank 211: P-Value = 0.219, Critical Value = 0.011
# Rank 212: P-Value = 0.219, Critical Value = 0.011
# Rank 213: P-Value = 0.219, Critical Value = 0.011
# Rank 214: P-Value = 0.220, Critical Value = 0.011
# Rank 215: P-Value = 0.220, Critical Value = 0.011
# Rank 216: P-Value = 0.220, Critical Value = 0.011
# Rank 217: P-Value = 0.223, Critical Value = 0.011
# Rank 218: P-Value = 0.224, Critical Value = 0.011
# Rank 219: P-Value = 0.224, Critical Value = 0.011
# Rank 220: P-Value = 0.225, Critical Value = 0.011
# Rank 221: P-Value = 0.225, Critical Value = 0.011
# Rank 222: P-Value = 0.227, Critical Value = 0.011
# Rank 223: P-Value = 0.229, Critical Value = 0.011
# Rank 224: P-Value = 0.229, Critical Value = 0.011
# Rank 225: P-Value = 0.230, Critical Value = 0.011
# Rank 226: P-Value = 0.232, Critical Value = 0.011
# Rank 227: P-Value = 0.233, Critical Value = 0.011
# Rank 228: P-Value = 0.233, Critical Value = 0.011
# Rank 229: P-Value = 0.234, Critical Value = 0.011
# Rank 230: P-Value = 0.235, Critical Value = 0.012
# Rank 231: P-Value = 0.236, Critical Value = 0.012
# Rank 232: P-Value = 0.236, Critical Value = 0.012
# Rank 233: P-Value = 0.238, Critical Value = 0.012
# Rank 234: P-Value = 0.239, Critical Value = 0.012
# Rank 235: P-Value = 0.239, Critical Value = 0.012
# Rank 236: P-Value = 0.240, Critical Value = 0.012
# Rank 237: P-Value = 0.241, Critical Value = 0.012
# Rank 238: P-Value = 0.245, Critical Value = 0.012
# Rank 239: P-Value = 0.246, Critical Value = 0.012
# Rank 240: P-Value = 0.247, Critical Value = 0.012
# Rank 241: P-Value = 0.247, Critical Value = 0.012
# Rank 242: P-Value = 0.249, Critical Value = 0.012
# Rank 243: P-Value = 0.251, Critical Value = 0.012
# Rank 244: P-Value = 0.252, Critical Value = 0.012
# Rank 245: P-Value = 0.253, Critical Value = 0.012
# Rank 246: P-Value = 0.253, Critical Value = 0.012
# Rank 247: P-Value = 0.255, Critical Value = 0.012
# Rank 248: P-Value = 0.255, Critical Value = 0.012
# Rank 249: P-Value = 0.257, Critical Value = 0.012
# Rank 250: P-Value = 0.257, Critical Value = 0.013
# Rank 251: P-Value = 0.258, Critical Value = 0.013
# Rank 252: P-Value = 0.258, Critical Value = 0.013
# Rank 253: P-Value = 0.258, Critical Value = 0.013
# Rank 254: P-Value = 0.258, Critical Value = 0.013
# Rank 255: P-Value = 0.259, Critical Value = 0.013
# Rank 256: P-Value = 0.260, Critical Value = 0.013
# Rank 257: P-Value = 0.260, Critical Value = 0.013
# Rank 258: P-Value = 0.261, Critical Value = 0.013
# Rank 259: P-Value = 0.263, Critical Value = 0.013
# Rank 260: P-Value = 0.263, Critical Value = 0.013
# Rank 261: P-Value = 0.263, Critical Value = 0.013
# Rank 262: P-Value = 0.265, Critical Value = 0.013
# Rank 263: P-Value = 0.268, Critical Value = 0.013
# Rank 264: P-Value = 0.268, Critical Value = 0.013
# Rank 265: P-Value = 0.269, Critical Value = 0.013
# Rank 266: P-Value = 0.270, Critical Value = 0.013
# Rank 267: P-Value = 0.271, Critical Value = 0.013
# Rank 268: P-Value = 0.271, Critical Value = 0.013
# Rank 269: P-Value = 0.273, Critical Value = 0.013
# Rank 270: P-Value = 0.274, Critical Value = 0.014
# Rank 271: P-Value = 0.275, Critical Value = 0.014
# Rank 272: P-Value = 0.275, Critical Value = 0.014
# Rank 273: P-Value = 0.276, Critical Value = 0.014
# Rank 274: P-Value = 0.277, Critical Value = 0.014
# Rank 275: P-Value = 0.279, Critical Value = 0.014
# Rank 276: P-Value = 0.280, Critical Value = 0.014
# Rank 277: P-Value = 0.281, Critical Value = 0.014
# Rank 278: P-Value = 0.283, Critical Value = 0.014
# Rank 279: P-Value = 0.284, Critical Value = 0.014
# Rank 280: P-Value = 0.285, Critical Value = 0.014
# Rank 281: P-Value = 0.286, Critical Value = 0.014
# Rank 282: P-Value = 0.287, Critical Value = 0.014
# Rank 283: P-Value = 0.293, Critical Value = 0.014
# Rank 284: P-Value = 0.293, Critical Value = 0.014
# Rank 285: P-Value = 0.295, Critical Value = 0.014
# Rank 286: P-Value = 0.295, Critical Value = 0.014
# Rank 287: P-Value = 0.296, Critical Value = 0.014
# Rank 288: P-Value = 0.297, Critical Value = 0.014
# Rank 289: P-Value = 0.297, Critical Value = 0.014
# Rank 290: P-Value = 0.298, Critical Value = 0.014
# Rank 291: P-Value = 0.298, Critical Value = 0.015
# Rank 292: P-Value = 0.300, Critical Value = 0.015
# Rank 293: P-Value = 0.300, Critical Value = 0.015
# Rank 294: P-Value = 0.301, Critical Value = 0.015
# Rank 295: P-Value = 0.302, Critical Value = 0.015
# Rank 296: P-Value = 0.302, Critical Value = 0.015
# Rank 297: P-Value = 0.302, Critical Value = 0.015
# Rank 298: P-Value = 0.302, Critical Value = 0.015
# Rank 299: P-Value = 0.304, Critical Value = 0.015
# Rank 300: P-Value = 0.305, Critical Value = 0.015
# Rank 301: P-Value = 0.305, Critical Value = 0.015
# Rank 302: P-Value = 0.306, Critical Value = 0.015
# Rank 303: P-Value = 0.307, Critical Value = 0.015
# Rank 304: P-Value = 0.308, Critical Value = 0.015
# Rank 305: P-Value = 0.312, Critical Value = 0.015
# Rank 306: P-Value = 0.312, Critical Value = 0.015
# Rank 307: P-Value = 0.315, Critical Value = 0.015
# Rank 308: P-Value = 0.317, Critical Value = 0.015
# Rank 309: P-Value = 0.317, Critical Value = 0.015
# Rank 310: P-Value = 0.318, Critical Value = 0.015
# Rank 311: P-Value = 0.320, Critical Value = 0.016
# Rank 312: P-Value = 0.320, Critical Value = 0.016
# Rank 313: P-Value = 0.321, Critical Value = 0.016
# Rank 314: P-Value = 0.323, Critical Value = 0.016
# Rank 315: P-Value = 0.324, Critical Value = 0.016
# Rank 316: P-Value = 0.324, Critical Value = 0.016
# Rank 317: P-Value = 0.325, Critical Value = 0.016
# Rank 318: P-Value = 0.325, Critical Value = 0.016
# Rank 319: P-Value = 0.325, Critical Value = 0.016
# Rank 320: P-Value = 0.330, Critical Value = 0.016
# Rank 321: P-Value = 0.333, Critical Value = 0.016
# Rank 322: P-Value = 0.334, Critical Value = 0.016
# Rank 323: P-Value = 0.336, Critical Value = 0.016
# Rank 324: P-Value = 0.336, Critical Value = 0.016
# Rank 325: P-Value = 0.336, Critical Value = 0.016
# Rank 326: P-Value = 0.336, Critical Value = 0.016
# Rank 327: P-Value = 0.336, Critical Value = 0.016
# Rank 328: P-Value = 0.337, Critical Value = 0.016
# Rank 329: P-Value = 0.337, Critical Value = 0.016
# Rank 330: P-Value = 0.340, Critical Value = 0.017
# Rank 331: P-Value = 0.341, Critical Value = 0.017
# Rank 332: P-Value = 0.341, Critical Value = 0.017
# Rank 333: P-Value = 0.342, Critical Value = 0.017
# Rank 334: P-Value = 0.343, Critical Value = 0.017
# Rank 335: P-Value = 0.344, Critical Value = 0.017
# Rank 336: P-Value = 0.345, Critical Value = 0.017
# Rank 337: P-Value = 0.346, Critical Value = 0.017
# Rank 338: P-Value = 0.347, Critical Value = 0.017
# Rank 339: P-Value = 0.347, Critical Value = 0.017
# Rank 340: P-Value = 0.349, Critical Value = 0.017
# Rank 341: P-Value = 0.350, Critical Value = 0.017
# Rank 342: P-Value = 0.351, Critical Value = 0.017
# Rank 343: P-Value = 0.351, Critical Value = 0.017
# Rank 344: P-Value = 0.352, Critical Value = 0.017
# Rank 345: P-Value = 0.352, Critical Value = 0.017
# Rank 346: P-Value = 0.353, Critical Value = 0.017
# Rank 347: P-Value = 0.353, Critical Value = 0.017
# Rank 348: P-Value = 0.354, Critical Value = 0.017
# Rank 349: P-Value = 0.354, Critical Value = 0.017
# Rank 350: P-Value = 0.355, Critical Value = 0.017
# Rank 351: P-Value = 0.356, Critical Value = 0.018
# Rank 352: P-Value = 0.356, Critical Value = 0.018
# Rank 353: P-Value = 0.357, Critical Value = 0.018
# Rank 354: P-Value = 0.358, Critical Value = 0.018
# Rank 355: P-Value = 0.360, Critical Value = 0.018
# Rank 356: P-Value = 0.361, Critical Value = 0.018
# Rank 357: P-Value = 0.362, Critical Value = 0.018
# Rank 358: P-Value = 0.363, Critical Value = 0.018
# Rank 359: P-Value = 0.366, Critical Value = 0.018
# Rank 360: P-Value = 0.367, Critical Value = 0.018
# Rank 361: P-Value = 0.370, Critical Value = 0.018
# Rank 362: P-Value = 0.371, Critical Value = 0.018
# Rank 363: P-Value = 0.372, Critical Value = 0.018
# Rank 364: P-Value = 0.372, Critical Value = 0.018
# Rank 365: P-Value = 0.374, Critical Value = 0.018
# Rank 366: P-Value = 0.375, Critical Value = 0.018
# Rank 367: P-Value = 0.375, Critical Value = 0.018
# Rank 368: P-Value = 0.376, Critical Value = 0.018
# Rank 369: P-Value = 0.377, Critical Value = 0.018
# Rank 370: P-Value = 0.377, Critical Value = 0.018
# Rank 371: P-Value = 0.378, Critical Value = 0.019
# Rank 372: P-Value = 0.378, Critical Value = 0.019
# Rank 373: P-Value = 0.380, Critical Value = 0.019
# Rank 374: P-Value = 0.381, Critical Value = 0.019
# Rank 375: P-Value = 0.381, Critical Value = 0.019
# Rank 376: P-Value = 0.382, Critical Value = 0.019
# Rank 377: P-Value = 0.384, Critical Value = 0.019
# Rank 378: P-Value = 0.386, Critical Value = 0.019
# Rank 379: P-Value = 0.388, Critical Value = 0.019
# Rank 380: P-Value = 0.389, Critical Value = 0.019
# Rank 381: P-Value = 0.390, Critical Value = 0.019
# Rank 382: P-Value = 0.390, Critical Value = 0.019
# Rank 383: P-Value = 0.391, Critical Value = 0.019
# Rank 384: P-Value = 0.391, Critical Value = 0.019
# Rank 385: P-Value = 0.392, Critical Value = 0.019
# Rank 386: P-Value = 0.392, Critical Value = 0.019
# Rank 387: P-Value = 0.392, Critical Value = 0.019
# Rank 388: P-Value = 0.395, Critical Value = 0.019
# Rank 389: P-Value = 0.397, Critical Value = 0.019
# Rank 390: P-Value = 0.401, Critical Value = 0.020
# Rank 391: P-Value = 0.402, Critical Value = 0.020
# Rank 392: P-Value = 0.406, Critical Value = 0.020
# Rank 393: P-Value = 0.406, Critical Value = 0.020
# Rank 394: P-Value = 0.406, Critical Value = 0.020
# Rank 395: P-Value = 0.408, Critical Value = 0.020
# Rank 396: P-Value = 0.408, Critical Value = 0.020
# Rank 397: P-Value = 0.411, Critical Value = 0.020
# Rank 398: P-Value = 0.411, Critical Value = 0.020
# Rank 399: P-Value = 0.411, Critical Value = 0.020
# Rank 400: P-Value = 0.413, Critical Value = 0.020
# Rank 401: P-Value = 0.413, Critical Value = 0.020
# Rank 402: P-Value = 0.414, Critical Value = 0.020
# Rank 403: P-Value = 0.418, Critical Value = 0.020
# Rank 404: P-Value = 0.419, Critical Value = 0.020
# Rank 405: P-Value = 0.419, Critical Value = 0.020
# Rank 406: P-Value = 0.419, Critical Value = 0.020
# Rank 407: P-Value = 0.420, Critical Value = 0.020
# Rank 408: P-Value = 0.420, Critical Value = 0.020
# Rank 409: P-Value = 0.421, Critical Value = 0.020
# Rank 410: P-Value = 0.421, Critical Value = 0.021
# Rank 411: P-Value = 0.424, Critical Value = 0.021
# Rank 412: P-Value = 0.424, Critical Value = 0.021
# Rank 413: P-Value = 0.425, Critical Value = 0.021
# Rank 414: P-Value = 0.425, Critical Value = 0.021
# Rank 415: P-Value = 0.426, Critical Value = 0.021
# Rank 416: P-Value = 0.427, Critical Value = 0.021
# Rank 417: P-Value = 0.427, Critical Value = 0.021
# Rank 418: P-Value = 0.428, Critical Value = 0.021
# Rank 419: P-Value = 0.429, Critical Value = 0.021
# Rank 420: P-Value = 0.431, Critical Value = 0.021
# Rank 421: P-Value = 0.431, Critical Value = 0.021
# Rank 422: P-Value = 0.432, Critical Value = 0.021
# Rank 423: P-Value = 0.432, Critical Value = 0.021
# Rank 424: P-Value = 0.434, Critical Value = 0.021
# Rank 425: P-Value = 0.435, Critical Value = 0.021
# Rank 426: P-Value = 0.435, Critical Value = 0.021
# Rank 427: P-Value = 0.436, Critical Value = 0.021
# Rank 428: P-Value = 0.438, Critical Value = 0.021
# Rank 429: P-Value = 0.441, Critical Value = 0.021
# Rank 430: P-Value = 0.443, Critical Value = 0.022
# Rank 431: P-Value = 0.443, Critical Value = 0.022
# Rank 432: P-Value = 0.445, Critical Value = 0.022
# Rank 433: P-Value = 0.446, Critical Value = 0.022
# Rank 434: P-Value = 0.448, Critical Value = 0.022
# Rank 435: P-Value = 0.448, Critical Value = 0.022
# Rank 436: P-Value = 0.448, Critical Value = 0.022
# Rank 437: P-Value = 0.449, Critical Value = 0.022
# Rank 438: P-Value = 0.450, Critical Value = 0.022
# Rank 439: P-Value = 0.450, Critical Value = 0.022
# Rank 440: P-Value = 0.451, Critical Value = 0.022
# Rank 441: P-Value = 0.451, Critical Value = 0.022
# Rank 442: P-Value = 0.452, Critical Value = 0.022
# Rank 443: P-Value = 0.452, Critical Value = 0.022
# Rank 444: P-Value = 0.453, Critical Value = 0.022
# Rank 445: P-Value = 0.455, Critical Value = 0.022
# Rank 446: P-Value = 0.455, Critical Value = 0.022
# Rank 447: P-Value = 0.456, Critical Value = 0.022
# Rank 448: P-Value = 0.456, Critical Value = 0.022
# Rank 449: P-Value = 0.456, Critical Value = 0.022
# Rank 450: P-Value = 0.458, Critical Value = 0.023
# Rank 451: P-Value = 0.461, Critical Value = 0.023
# Rank 452: P-Value = 0.462, Critical Value = 0.023
# Rank 453: P-Value = 0.462, Critical Value = 0.023
# Rank 454: P-Value = 0.464, Critical Value = 0.023
# Rank 455: P-Value = 0.464, Critical Value = 0.023
# Rank 456: P-Value = 0.464, Critical Value = 0.023
# Rank 457: P-Value = 0.465, Critical Value = 0.023
# Rank 458: P-Value = 0.465, Critical Value = 0.023
# Rank 459: P-Value = 0.466, Critical Value = 0.023
# Rank 460: P-Value = 0.467, Critical Value = 0.023
# Rank 461: P-Value = 0.469, Critical Value = 0.023
# Rank 462: P-Value = 0.470, Critical Value = 0.023
# Rank 463: P-Value = 0.470, Critical Value = 0.023
# Rank 464: P-Value = 0.470, Critical Value = 0.023
# Rank 465: P-Value = 0.471, Critical Value = 0.023
# Rank 466: P-Value = 0.471, Critical Value = 0.023
# Rank 467: P-Value = 0.472, Critical Value = 0.023
# Rank 468: P-Value = 0.472, Critical Value = 0.023
# Rank 469: P-Value = 0.472, Critical Value = 0.023
# Rank 470: P-Value = 0.477, Critical Value = 0.024
# Rank 471: P-Value = 0.478, Critical Value = 0.024
# Rank 472: P-Value = 0.478, Critical Value = 0.024
# Rank 473: P-Value = 0.481, Critical Value = 0.024
# Rank 474: P-Value = 0.481, Critical Value = 0.024
# Rank 475: P-Value = 0.482, Critical Value = 0.024
# Rank 476: P-Value = 0.483, Critical Value = 0.024
# Rank 477: P-Value = 0.485, Critical Value = 0.024
# Rank 478: P-Value = 0.486, Critical Value = 0.024
# Rank 479: P-Value = 0.487, Critical Value = 0.024
# Rank 480: P-Value = 0.488, Critical Value = 0.024
# Rank 481: P-Value = 0.488, Critical Value = 0.024
# Rank 482: P-Value = 0.488, Critical Value = 0.024
# Rank 483: P-Value = 0.488, Critical Value = 0.024
# Rank 484: P-Value = 0.489, Critical Value = 0.024
# Rank 485: P-Value = 0.489, Critical Value = 0.024
# Rank 486: P-Value = 0.491, Critical Value = 0.024
# Rank 487: P-Value = 0.491, Critical Value = 0.024
# Rank 488: P-Value = 0.492, Critical Value = 0.024
# Rank 489: P-Value = 0.493, Critical Value = 0.024
# Rank 490: P-Value = 0.494, Critical Value = 0.025
# Rank 491: P-Value = 0.494, Critical Value = 0.025
# Rank 492: P-Value = 0.497, Critical Value = 0.025
# Rank 493: P-Value = 0.498, Critical Value = 0.025
# Rank 494: P-Value = 0.498, Critical Value = 0.025
# Rank 495: P-Value = 0.500, Critical Value = 0.025
# Rank 496: P-Value = 0.503, Critical Value = 0.025
# Rank 497: P-Value = 0.505, Critical Value = 0.025
# Rank 498: P-Value = 0.508, Critical Value = 0.025
# Rank 499: P-Value = 0.510, Critical Value = 0.025
# Rank 500: P-Value = 0.510, Critical Value = 0.025
# Rank 501: P-Value = 0.511, Critical Value = 0.025
# Rank 502: P-Value = 0.511, Critical Value = 0.025
# Rank 503: P-Value = 0.512, Critical Value = 0.025
# Rank 504: P-Value = 0.512, Critical Value = 0.025
# Rank 505: P-Value = 0.512, Critical Value = 0.025
# Rank 506: P-Value = 0.513, Critical Value = 0.025
# Rank 507: P-Value = 0.513, Critical Value = 0.025
# Rank 508: P-Value = 0.513, Critical Value = 0.025
# Rank 509: P-Value = 0.513, Critical Value = 0.025
# Rank 510: P-Value = 0.513, Critical Value = 0.026
# Rank 511: P-Value = 0.514, Critical Value = 0.026
# Rank 512: P-Value = 0.514, Critical Value = 0.026
# Rank 513: P-Value = 0.515, Critical Value = 0.026
# Rank 514: P-Value = 0.516, Critical Value = 0.026
# Rank 515: P-Value = 0.516, Critical Value = 0.026
# Rank 516: P-Value = 0.518, Critical Value = 0.026
# Rank 517: P-Value = 0.519, Critical Value = 0.026
# Rank 518: P-Value = 0.519, Critical Value = 0.026
# Rank 519: P-Value = 0.520, Critical Value = 0.026
# Rank 520: P-Value = 0.522, Critical Value = 0.026
# Rank 521: P-Value = 0.524, Critical Value = 0.026
# Rank 522: P-Value = 0.526, Critical Value = 0.026
# Rank 523: P-Value = 0.526, Critical Value = 0.026
# Rank 524: P-Value = 0.527, Critical Value = 0.026
# Rank 525: P-Value = 0.530, Critical Value = 0.026
# Rank 526: P-Value = 0.530, Critical Value = 0.026
# Rank 527: P-Value = 0.531, Critical Value = 0.026
# Rank 528: P-Value = 0.531, Critical Value = 0.026
# Rank 529: P-Value = 0.532, Critical Value = 0.026
# Rank 530: P-Value = 0.533, Critical Value = 0.027
# Rank 531: P-Value = 0.534, Critical Value = 0.027
# Rank 532: P-Value = 0.536, Critical Value = 0.027
# Rank 533: P-Value = 0.537, Critical Value = 0.027
# Rank 534: P-Value = 0.538, Critical Value = 0.027
# Rank 535: P-Value = 0.538, Critical Value = 0.027
# Rank 536: P-Value = 0.541, Critical Value = 0.027
# Rank 537: P-Value = 0.542, Critical Value = 0.027
# Rank 538: P-Value = 0.542, Critical Value = 0.027
# Rank 539: P-Value = 0.543, Critical Value = 0.027
# Rank 540: P-Value = 0.544, Critical Value = 0.027
# Rank 541: P-Value = 0.546, Critical Value = 0.027
# Rank 542: P-Value = 0.546, Critical Value = 0.027
# Rank 543: P-Value = 0.546, Critical Value = 0.027
# Rank 544: P-Value = 0.546, Critical Value = 0.027
# Rank 545: P-Value = 0.549, Critical Value = 0.027
# Rank 546: P-Value = 0.553, Critical Value = 0.027
# Rank 547: P-Value = 0.554, Critical Value = 0.027
# Rank 548: P-Value = 0.554, Critical Value = 0.027
# Rank 549: P-Value = 0.555, Critical Value = 0.027
# Rank 550: P-Value = 0.555, Critical Value = 0.028
# Rank 551: P-Value = 0.556, Critical Value = 0.028
# Rank 552: P-Value = 0.557, Critical Value = 0.028
# Rank 553: P-Value = 0.560, Critical Value = 0.028
# Rank 554: P-Value = 0.560, Critical Value = 0.028
# Rank 555: P-Value = 0.561, Critical Value = 0.028
# Rank 556: P-Value = 0.562, Critical Value = 0.028
# Rank 557: P-Value = 0.562, Critical Value = 0.028
# Rank 558: P-Value = 0.563, Critical Value = 0.028
# Rank 559: P-Value = 0.564, Critical Value = 0.028
# Rank 560: P-Value = 0.564, Critical Value = 0.028
# Rank 561: P-Value = 0.565, Critical Value = 0.028
# Rank 562: P-Value = 0.568, Critical Value = 0.028
# Rank 563: P-Value = 0.568, Critical Value = 0.028
# Rank 564: P-Value = 0.569, Critical Value = 0.028
# Rank 565: P-Value = 0.569, Critical Value = 0.028
# Rank 566: P-Value = 0.570, Critical Value = 0.028
# Rank 567: P-Value = 0.573, Critical Value = 0.028
# Rank 568: P-Value = 0.575, Critical Value = 0.028
# Rank 569: P-Value = 0.577, Critical Value = 0.028
# Rank 570: P-Value = 0.577, Critical Value = 0.028
# Rank 571: P-Value = 0.578, Critical Value = 0.029
# Rank 572: P-Value = 0.578, Critical Value = 0.029
# Rank 573: P-Value = 0.578, Critical Value = 0.029
# Rank 574: P-Value = 0.578, Critical Value = 0.029
# Rank 575: P-Value = 0.579, Critical Value = 0.029
# Rank 576: P-Value = 0.582, Critical Value = 0.029
# Rank 577: P-Value = 0.582, Critical Value = 0.029
# Rank 578: P-Value = 0.583, Critical Value = 0.029
# Rank 579: P-Value = 0.583, Critical Value = 0.029
# Rank 580: P-Value = 0.583, Critical Value = 0.029
# Rank 581: P-Value = 0.584, Critical Value = 0.029
# Rank 582: P-Value = 0.585, Critical Value = 0.029
# Rank 583: P-Value = 0.586, Critical Value = 0.029
# Rank 584: P-Value = 0.587, Critical Value = 0.029
# Rank 585: P-Value = 0.587, Critical Value = 0.029
# Rank 586: P-Value = 0.588, Critical Value = 0.029
# Rank 587: P-Value = 0.588, Critical Value = 0.029
# Rank 588: P-Value = 0.590, Critical Value = 0.029
# Rank 589: P-Value = 0.591, Critical Value = 0.029
# Rank 590: P-Value = 0.592, Critical Value = 0.029
# Rank 591: P-Value = 0.592, Critical Value = 0.030
# Rank 592: P-Value = 0.594, Critical Value = 0.030
# Rank 593: P-Value = 0.594, Critical Value = 0.030
# Rank 594: P-Value = 0.595, Critical Value = 0.030
# Rank 595: P-Value = 0.595, Critical Value = 0.030
# Rank 596: P-Value = 0.596, Critical Value = 0.030
# Rank 597: P-Value = 0.603, Critical Value = 0.030
# Rank 598: P-Value = 0.604, Critical Value = 0.030
# Rank 599: P-Value = 0.604, Critical Value = 0.030
# Rank 600: P-Value = 0.605, Critical Value = 0.030
# Rank 601: P-Value = 0.605, Critical Value = 0.030
# Rank 602: P-Value = 0.606, Critical Value = 0.030
# Rank 603: P-Value = 0.606, Critical Value = 0.030
# Rank 604: P-Value = 0.608, Critical Value = 0.030
# Rank 605: P-Value = 0.609, Critical Value = 0.030
# Rank 606: P-Value = 0.610, Critical Value = 0.030
# Rank 607: P-Value = 0.612, Critical Value = 0.030
# Rank 608: P-Value = 0.615, Critical Value = 0.030
# Rank 609: P-Value = 0.616, Critical Value = 0.030
# Rank 610: P-Value = 0.618, Critical Value = 0.030
# Rank 611: P-Value = 0.618, Critical Value = 0.031
# Rank 612: P-Value = 0.619, Critical Value = 0.031
# Rank 613: P-Value = 0.621, Critical Value = 0.031
# Rank 614: P-Value = 0.622, Critical Value = 0.031
# Rank 615: P-Value = 0.622, Critical Value = 0.031
# Rank 616: P-Value = 0.623, Critical Value = 0.031
# Rank 617: P-Value = 0.625, Critical Value = 0.031
# Rank 618: P-Value = 0.627, Critical Value = 0.031
# Rank 619: P-Value = 0.627, Critical Value = 0.031
# Rank 620: P-Value = 0.627, Critical Value = 0.031
# Rank 621: P-Value = 0.628, Critical Value = 0.031
# Rank 622: P-Value = 0.628, Critical Value = 0.031
# Rank 623: P-Value = 0.629, Critical Value = 0.031
# Rank 624: P-Value = 0.629, Critical Value = 0.031
# Rank 625: P-Value = 0.630, Critical Value = 0.031
# Rank 626: P-Value = 0.630, Critical Value = 0.031
# Rank 627: P-Value = 0.631, Critical Value = 0.031
# Rank 628: P-Value = 0.631, Critical Value = 0.031
# Rank 629: P-Value = 0.632, Critical Value = 0.031
# Rank 630: P-Value = 0.632, Critical Value = 0.032
# Rank 631: P-Value = 0.632, Critical Value = 0.032
# Rank 632: P-Value = 0.634, Critical Value = 0.032
# Rank 633: P-Value = 0.636, Critical Value = 0.032
# Rank 634: P-Value = 0.637, Critical Value = 0.032
# Rank 635: P-Value = 0.638, Critical Value = 0.032
# Rank 636: P-Value = 0.639, Critical Value = 0.032
# Rank 637: P-Value = 0.639, Critical Value = 0.032
# Rank 638: P-Value = 0.640, Critical Value = 0.032
# Rank 639: P-Value = 0.640, Critical Value = 0.032
# Rank 640: P-Value = 0.642, Critical Value = 0.032
# Rank 641: P-Value = 0.643, Critical Value = 0.032
# Rank 642: P-Value = 0.643, Critical Value = 0.032
# Rank 643: P-Value = 0.645, Critical Value = 0.032
# Rank 644: P-Value = 0.647, Critical Value = 0.032
# Rank 645: P-Value = 0.648, Critical Value = 0.032
# Rank 646: P-Value = 0.648, Critical Value = 0.032
# Rank 647: P-Value = 0.650, Critical Value = 0.032
# Rank 648: P-Value = 0.650, Critical Value = 0.032
# Rank 649: P-Value = 0.651, Critical Value = 0.032
# Rank 650: P-Value = 0.652, Critical Value = 0.033
# Rank 651: P-Value = 0.653, Critical Value = 0.033
# Rank 652: P-Value = 0.653, Critical Value = 0.033
# Rank 653: P-Value = 0.653, Critical Value = 0.033
# Rank 654: P-Value = 0.653, Critical Value = 0.033
# Rank 655: P-Value = 0.654, Critical Value = 0.033
# Rank 656: P-Value = 0.655, Critical Value = 0.033
# Rank 657: P-Value = 0.655, Critical Value = 0.033
# Rank 658: P-Value = 0.655, Critical Value = 0.033
# Rank 659: P-Value = 0.655, Critical Value = 0.033
# Rank 660: P-Value = 0.656, Critical Value = 0.033
# Rank 661: P-Value = 0.656, Critical Value = 0.033
# Rank 662: P-Value = 0.656, Critical Value = 0.033
# Rank 663: P-Value = 0.657, Critical Value = 0.033
# Rank 664: P-Value = 0.658, Critical Value = 0.033
# Rank 665: P-Value = 0.658, Critical Value = 0.033
# Rank 666: P-Value = 0.659, Critical Value = 0.033
# Rank 667: P-Value = 0.662, Critical Value = 0.033
# Rank 668: P-Value = 0.662, Critical Value = 0.033
# Rank 669: P-Value = 0.663, Critical Value = 0.033
# Rank 670: P-Value = 0.663, Critical Value = 0.034
# Rank 671: P-Value = 0.667, Critical Value = 0.034
# Rank 672: P-Value = 0.671, Critical Value = 0.034
# Rank 673: P-Value = 0.674, Critical Value = 0.034
# Rank 674: P-Value = 0.676, Critical Value = 0.034
# Rank 675: P-Value = 0.677, Critical Value = 0.034
# Rank 676: P-Value = 0.677, Critical Value = 0.034
# Rank 677: P-Value = 0.678, Critical Value = 0.034
# Rank 678: P-Value = 0.679, Critical Value = 0.034
# Rank 679: P-Value = 0.679, Critical Value = 0.034
# Rank 680: P-Value = 0.679, Critical Value = 0.034
# Rank 681: P-Value = 0.681, Critical Value = 0.034
# Rank 682: P-Value = 0.682, Critical Value = 0.034
# Rank 683: P-Value = 0.683, Critical Value = 0.034
# Rank 684: P-Value = 0.683, Critical Value = 0.034
# Rank 685: P-Value = 0.684, Critical Value = 0.034
# Rank 686: P-Value = 0.684, Critical Value = 0.034
# Rank 687: P-Value = 0.686, Critical Value = 0.034
# Rank 688: P-Value = 0.687, Critical Value = 0.034
# Rank 689: P-Value = 0.687, Critical Value = 0.034
# Rank 690: P-Value = 0.687, Critical Value = 0.034
# Rank 691: P-Value = 0.688, Critical Value = 0.035
# Rank 692: P-Value = 0.688, Critical Value = 0.035
# Rank 693: P-Value = 0.689, Critical Value = 0.035
# Rank 694: P-Value = 0.689, Critical Value = 0.035
# Rank 695: P-Value = 0.690, Critical Value = 0.035
# Rank 696: P-Value = 0.691, Critical Value = 0.035
# Rank 697: P-Value = 0.692, Critical Value = 0.035
# Rank 698: P-Value = 0.693, Critical Value = 0.035
# Rank 699: P-Value = 0.693, Critical Value = 0.035
# Rank 700: P-Value = 0.693, Critical Value = 0.035
# Rank 701: P-Value = 0.693, Critical Value = 0.035
# Rank 702: P-Value = 0.695, Critical Value = 0.035
# Rank 703: P-Value = 0.696, Critical Value = 0.035
# Rank 704: P-Value = 0.697, Critical Value = 0.035
# Rank 705: P-Value = 0.697, Critical Value = 0.035
# Rank 706: P-Value = 0.698, Critical Value = 0.035
# Rank 707: P-Value = 0.699, Critical Value = 0.035
# Rank 708: P-Value = 0.700, Critical Value = 0.035
# Rank 709: P-Value = 0.700, Critical Value = 0.035
# Rank 710: P-Value = 0.704, Critical Value = 0.035
# Rank 711: P-Value = 0.705, Critical Value = 0.036
# Rank 712: P-Value = 0.705, Critical Value = 0.036
# Rank 713: P-Value = 0.705, Critical Value = 0.036
# Rank 714: P-Value = 0.706, Critical Value = 0.036
# Rank 715: P-Value = 0.706, Critical Value = 0.036
# Rank 716: P-Value = 0.706, Critical Value = 0.036
# Rank 717: P-Value = 0.710, Critical Value = 0.036
# Rank 718: P-Value = 0.710, Critical Value = 0.036
# Rank 719: P-Value = 0.711, Critical Value = 0.036
# Rank 720: P-Value = 0.711, Critical Value = 0.036
# Rank 721: P-Value = 0.711, Critical Value = 0.036
# Rank 722: P-Value = 0.712, Critical Value = 0.036
# Rank 723: P-Value = 0.712, Critical Value = 0.036
# Rank 724: P-Value = 0.713, Critical Value = 0.036
# Rank 725: P-Value = 0.714, Critical Value = 0.036
# Rank 726: P-Value = 0.714, Critical Value = 0.036
# Rank 727: P-Value = 0.715, Critical Value = 0.036
# Rank 728: P-Value = 0.715, Critical Value = 0.036
# Rank 729: P-Value = 0.716, Critical Value = 0.036
# Rank 730: P-Value = 0.716, Critical Value = 0.036
# Rank 731: P-Value = 0.717, Critical Value = 0.037
# Rank 732: P-Value = 0.719, Critical Value = 0.037
# Rank 733: P-Value = 0.719, Critical Value = 0.037
# Rank 734: P-Value = 0.720, Critical Value = 0.037
# Rank 735: P-Value = 0.720, Critical Value = 0.037
# Rank 736: P-Value = 0.721, Critical Value = 0.037
# Rank 737: P-Value = 0.723, Critical Value = 0.037
# Rank 738: P-Value = 0.724, Critical Value = 0.037
# Rank 739: P-Value = 0.725, Critical Value = 0.037
# Rank 740: P-Value = 0.726, Critical Value = 0.037
# Rank 741: P-Value = 0.727, Critical Value = 0.037
# Rank 742: P-Value = 0.730, Critical Value = 0.037
# Rank 743: P-Value = 0.731, Critical Value = 0.037
# Rank 744: P-Value = 0.731, Critical Value = 0.037
# Rank 745: P-Value = 0.733, Critical Value = 0.037
# Rank 746: P-Value = 0.735, Critical Value = 0.037
# Rank 747: P-Value = 0.735, Critical Value = 0.037
# Rank 748: P-Value = 0.736, Critical Value = 0.037
# Rank 749: P-Value = 0.738, Critical Value = 0.037
# Rank 750: P-Value = 0.738, Critical Value = 0.038
# Rank 751: P-Value = 0.738, Critical Value = 0.038
# Rank 752: P-Value = 0.739, Critical Value = 0.038
# Rank 753: P-Value = 0.740, Critical Value = 0.038
# Rank 754: P-Value = 0.742, Critical Value = 0.038
# Rank 755: P-Value = 0.743, Critical Value = 0.038
# Rank 756: P-Value = 0.745, Critical Value = 0.038
# Rank 757: P-Value = 0.745, Critical Value = 0.038
# Rank 758: P-Value = 0.746, Critical Value = 0.038
# Rank 759: P-Value = 0.748, Critical Value = 0.038
# Rank 760: P-Value = 0.750, Critical Value = 0.038
# Rank 761: P-Value = 0.750, Critical Value = 0.038
# Rank 762: P-Value = 0.750, Critical Value = 0.038
# Rank 763: P-Value = 0.752, Critical Value = 0.038
# Rank 764: P-Value = 0.755, Critical Value = 0.038
# Rank 765: P-Value = 0.756, Critical Value = 0.038
# Rank 766: P-Value = 0.757, Critical Value = 0.038
# Rank 767: P-Value = 0.758, Critical Value = 0.038
# Rank 768: P-Value = 0.759, Critical Value = 0.038
# Rank 769: P-Value = 0.759, Critical Value = 0.038
# Rank 770: P-Value = 0.760, Critical Value = 0.039
# Rank 771: P-Value = 0.760, Critical Value = 0.039
# Rank 772: P-Value = 0.762, Critical Value = 0.039
# Rank 773: P-Value = 0.762, Critical Value = 0.039
# Rank 774: P-Value = 0.762, Critical Value = 0.039
# Rank 775: P-Value = 0.763, Critical Value = 0.039
# Rank 776: P-Value = 0.764, Critical Value = 0.039
# Rank 777: P-Value = 0.764, Critical Value = 0.039
# Rank 778: P-Value = 0.764, Critical Value = 0.039
# Rank 779: P-Value = 0.764, Critical Value = 0.039
# Rank 780: P-Value = 0.766, Critical Value = 0.039
# Rank 781: P-Value = 0.767, Critical Value = 0.039
# Rank 782: P-Value = 0.768, Critical Value = 0.039
# Rank 783: P-Value = 0.769, Critical Value = 0.039
# Rank 784: P-Value = 0.771, Critical Value = 0.039
# Rank 785: P-Value = 0.772, Critical Value = 0.039
# Rank 786: P-Value = 0.773, Critical Value = 0.039
# Rank 787: P-Value = 0.773, Critical Value = 0.039
# Rank 788: P-Value = 0.774, Critical Value = 0.039
# Rank 789: P-Value = 0.775, Critical Value = 0.039
# Rank 790: P-Value = 0.777, Critical Value = 0.040
# Rank 791: P-Value = 0.778, Critical Value = 0.040
# Rank 792: P-Value = 0.779, Critical Value = 0.040
# Rank 793: P-Value = 0.779, Critical Value = 0.040
# Rank 794: P-Value = 0.781, Critical Value = 0.040
# Rank 795: P-Value = 0.781, Critical Value = 0.040
# Rank 796: P-Value = 0.784, Critical Value = 0.040
# Rank 797: P-Value = 0.784, Critical Value = 0.040
# Rank 798: P-Value = 0.784, Critical Value = 0.040
# Rank 799: P-Value = 0.784, Critical Value = 0.040
# Rank 800: P-Value = 0.789, Critical Value = 0.040
# Rank 801: P-Value = 0.792, Critical Value = 0.040
# Rank 802: P-Value = 0.792, Critical Value = 0.040
# Rank 803: P-Value = 0.793, Critical Value = 0.040
# Rank 804: P-Value = 0.794, Critical Value = 0.040
# Rank 805: P-Value = 0.795, Critical Value = 0.040
# Rank 806: P-Value = 0.795, Critical Value = 0.040
# Rank 807: P-Value = 0.797, Critical Value = 0.040
# Rank 808: P-Value = 0.798, Critical Value = 0.040
# Rank 809: P-Value = 0.800, Critical Value = 0.040
# Rank 810: P-Value = 0.800, Critical Value = 0.041
# Rank 811: P-Value = 0.801, Critical Value = 0.041
# Rank 812: P-Value = 0.804, Critical Value = 0.041
# Rank 813: P-Value = 0.805, Critical Value = 0.041
# Rank 814: P-Value = 0.806, Critical Value = 0.041
# Rank 815: P-Value = 0.806, Critical Value = 0.041
# Rank 816: P-Value = 0.806, Critical Value = 0.041
# Rank 817: P-Value = 0.807, Critical Value = 0.041
# Rank 818: P-Value = 0.808, Critical Value = 0.041
# Rank 819: P-Value = 0.809, Critical Value = 0.041
# Rank 820: P-Value = 0.809, Critical Value = 0.041
# Rank 821: P-Value = 0.810, Critical Value = 0.041
# Rank 822: P-Value = 0.810, Critical Value = 0.041
# Rank 823: P-Value = 0.810, Critical Value = 0.041
# Rank 824: P-Value = 0.811, Critical Value = 0.041
# Rank 825: P-Value = 0.812, Critical Value = 0.041
# Rank 826: P-Value = 0.813, Critical Value = 0.041
# Rank 827: P-Value = 0.815, Critical Value = 0.041
# Rank 828: P-Value = 0.816, Critical Value = 0.041
# Rank 829: P-Value = 0.816, Critical Value = 0.041
# Rank 830: P-Value = 0.817, Critical Value = 0.042
# Rank 831: P-Value = 0.818, Critical Value = 0.042
# Rank 832: P-Value = 0.819, Critical Value = 0.042
# Rank 833: P-Value = 0.820, Critical Value = 0.042
# Rank 834: P-Value = 0.820, Critical Value = 0.042
# Rank 835: P-Value = 0.821, Critical Value = 0.042
# Rank 836: P-Value = 0.821, Critical Value = 0.042
# Rank 837: P-Value = 0.821, Critical Value = 0.042
# Rank 838: P-Value = 0.821, Critical Value = 0.042
# Rank 839: P-Value = 0.822, Critical Value = 0.042
# Rank 840: P-Value = 0.822, Critical Value = 0.042
# Rank 841: P-Value = 0.824, Critical Value = 0.042
# Rank 842: P-Value = 0.824, Critical Value = 0.042
# Rank 843: P-Value = 0.826, Critical Value = 0.042
# Rank 844: P-Value = 0.826, Critical Value = 0.042
# Rank 845: P-Value = 0.830, Critical Value = 0.042
# Rank 846: P-Value = 0.832, Critical Value = 0.042
# Rank 847: P-Value = 0.832, Critical Value = 0.042
# Rank 848: P-Value = 0.832, Critical Value = 0.042
# Rank 849: P-Value = 0.833, Critical Value = 0.042
# Rank 850: P-Value = 0.833, Critical Value = 0.043
# Rank 851: P-Value = 0.833, Critical Value = 0.043
# Rank 852: P-Value = 0.834, Critical Value = 0.043
# Rank 853: P-Value = 0.836, Critical Value = 0.043
# Rank 854: P-Value = 0.837, Critical Value = 0.043
# Rank 855: P-Value = 0.837, Critical Value = 0.043
# Rank 856: P-Value = 0.838, Critical Value = 0.043
# Rank 857: P-Value = 0.840, Critical Value = 0.043
# Rank 858: P-Value = 0.840, Critical Value = 0.043
# Rank 859: P-Value = 0.841, Critical Value = 0.043
# Rank 860: P-Value = 0.841, Critical Value = 0.043
# Rank 861: P-Value = 0.842, Critical Value = 0.043
# Rank 862: P-Value = 0.844, Critical Value = 0.043
# Rank 863: P-Value = 0.846, Critical Value = 0.043
# Rank 864: P-Value = 0.849, Critical Value = 0.043
# Rank 865: P-Value = 0.850, Critical Value = 0.043
# Rank 866: P-Value = 0.851, Critical Value = 0.043
# Rank 867: P-Value = 0.851, Critical Value = 0.043
# Rank 868: P-Value = 0.851, Critical Value = 0.043
# Rank 869: P-Value = 0.854, Critical Value = 0.043
# Rank 870: P-Value = 0.854, Critical Value = 0.044
# Rank 871: P-Value = 0.855, Critical Value = 0.044
# Rank 872: P-Value = 0.855, Critical Value = 0.044
# Rank 873: P-Value = 0.855, Critical Value = 0.044
# Rank 874: P-Value = 0.856, Critical Value = 0.044
# Rank 875: P-Value = 0.856, Critical Value = 0.044
# Rank 876: P-Value = 0.857, Critical Value = 0.044
# Rank 877: P-Value = 0.858, Critical Value = 0.044
# Rank 878: P-Value = 0.858, Critical Value = 0.044
# Rank 879: P-Value = 0.858, Critical Value = 0.044
# Rank 880: P-Value = 0.859, Critical Value = 0.044
# Rank 881: P-Value = 0.860, Critical Value = 0.044
# Rank 882: P-Value = 0.863, Critical Value = 0.044
# Rank 883: P-Value = 0.863, Critical Value = 0.044
# Rank 884: P-Value = 0.865, Critical Value = 0.044
# Rank 885: P-Value = 0.865, Critical Value = 0.044
# Rank 886: P-Value = 0.866, Critical Value = 0.044
# Rank 887: P-Value = 0.867, Critical Value = 0.044
# Rank 888: P-Value = 0.868, Critical Value = 0.044
# Rank 889: P-Value = 0.869, Critical Value = 0.044
# Rank 890: P-Value = 0.870, Critical Value = 0.045
# Rank 891: P-Value = 0.871, Critical Value = 0.045
# Rank 892: P-Value = 0.871, Critical Value = 0.045
# Rank 893: P-Value = 0.871, Critical Value = 0.045
# Rank 894: P-Value = 0.874, Critical Value = 0.045
# Rank 895: P-Value = 0.875, Critical Value = 0.045
# Rank 896: P-Value = 0.875, Critical Value = 0.045
# Rank 897: P-Value = 0.876, Critical Value = 0.045
# Rank 898: P-Value = 0.878, Critical Value = 0.045
# Rank 899: P-Value = 0.878, Critical Value = 0.045
# Rank 900: P-Value = 0.879, Critical Value = 0.045
# Rank 901: P-Value = 0.881, Critical Value = 0.045
# Rank 902: P-Value = 0.881, Critical Value = 0.045
# Rank 903: P-Value = 0.881, Critical Value = 0.045
# Rank 904: P-Value = 0.882, Critical Value = 0.045
# Rank 905: P-Value = 0.883, Critical Value = 0.045
# Rank 906: P-Value = 0.884, Critical Value = 0.045
# Rank 907: P-Value = 0.887, Critical Value = 0.045
# Rank 908: P-Value = 0.887, Critical Value = 0.045
# Rank 909: P-Value = 0.887, Critical Value = 0.045
# Rank 910: P-Value = 0.889, Critical Value = 0.046
# Rank 911: P-Value = 0.892, Critical Value = 0.046
# Rank 912: P-Value = 0.893, Critical Value = 0.046
# Rank 913: P-Value = 0.894, Critical Value = 0.046
# Rank 914: P-Value = 0.899, Critical Value = 0.046
# Rank 915: P-Value = 0.900, Critical Value = 0.046
# Rank 916: P-Value = 0.900, Critical Value = 0.046
# Rank 917: P-Value = 0.901, Critical Value = 0.046
# Rank 918: P-Value = 0.902, Critical Value = 0.046
# Rank 919: P-Value = 0.902, Critical Value = 0.046
# Rank 920: P-Value = 0.903, Critical Value = 0.046
# Rank 921: P-Value = 0.904, Critical Value = 0.046
# Rank 922: P-Value = 0.908, Critical Value = 0.046
# Rank 923: P-Value = 0.909, Critical Value = 0.046
# Rank 924: P-Value = 0.910, Critical Value = 0.046
# Rank 925: P-Value = 0.911, Critical Value = 0.046
# Rank 926: P-Value = 0.911, Critical Value = 0.046
# Rank 927: P-Value = 0.912, Critical Value = 0.046
# Rank 928: P-Value = 0.912, Critical Value = 0.046
# Rank 929: P-Value = 0.913, Critical Value = 0.046
# Rank 930: P-Value = 0.915, Critical Value = 0.047
# Rank 931: P-Value = 0.915, Critical Value = 0.047
# Rank 932: P-Value = 0.915, Critical Value = 0.047
# Rank 933: P-Value = 0.915, Critical Value = 0.047
# Rank 934: P-Value = 0.916, Critical Value = 0.047
# Rank 935: P-Value = 0.918, Critical Value = 0.047
# Rank 936: P-Value = 0.919, Critical Value = 0.047
# Rank 937: P-Value = 0.920, Critical Value = 0.047
# Rank 938: P-Value = 0.923, Critical Value = 0.047
# Rank 939: P-Value = 0.923, Critical Value = 0.047
# Rank 940: P-Value = 0.929, Critical Value = 0.047
# Rank 941: P-Value = 0.929, Critical Value = 0.047
# Rank 942: P-Value = 0.929, Critical Value = 0.047
# Rank 943: P-Value = 0.931, Critical Value = 0.047
# Rank 944: P-Value = 0.931, Critical Value = 0.047
# Rank 945: P-Value = 0.931, Critical Value = 0.047
# Rank 946: P-Value = 0.932, Critical Value = 0.047
# Rank 947: P-Value = 0.933, Critical Value = 0.047
# Rank 948: P-Value = 0.933, Critical Value = 0.047
# Rank 949: P-Value = 0.933, Critical Value = 0.047
# Rank 950: P-Value = 0.935, Critical Value = 0.048
# Rank 951: P-Value = 0.936, Critical Value = 0.048
# Rank 952: P-Value = 0.937, Critical Value = 0.048
# Rank 953: P-Value = 0.938, Critical Value = 0.048
# Rank 954: P-Value = 0.939, Critical Value = 0.048
# Rank 955: P-Value = 0.940, Critical Value = 0.048
# Rank 956: P-Value = 0.940, Critical Value = 0.048
# Rank 957: P-Value = 0.941, Critical Value = 0.048
# Rank 958: P-Value = 0.941, Critical Value = 0.048
# Rank 959: P-Value = 0.941, Critical Value = 0.048
# Rank 960: P-Value = 0.942, Critical Value = 0.048
# Rank 961: P-Value = 0.942, Critical Value = 0.048
# Rank 962: P-Value = 0.943, Critical Value = 0.048
# Rank 963: P-Value = 0.946, Critical Value = 0.048
# Rank 964: P-Value = 0.946, Critical Value = 0.048
# Rank 965: P-Value = 0.952, Critical Value = 0.048
# Rank 966: P-Value = 0.952, Critical Value = 0.048
# Rank 967: P-Value = 0.954, Critical Value = 0.048
# Rank 968: P-Value = 0.955, Critical Value = 0.048
# Rank 969: P-Value = 0.955, Critical Value = 0.048
# Rank 970: P-Value = 0.956, Critical Value = 0.049
# Rank 971: P-Value = 0.958, Critical Value = 0.049
# Rank 972: P-Value = 0.958, Critical Value = 0.049
# Rank 973: P-Value = 0.958, Critical Value = 0.049
# Rank 974: P-Value = 0.959, Critical Value = 0.049
# Rank 975: P-Value = 0.960, Critical Value = 0.049
# Rank 976: P-Value = 0.961, Critical Value = 0.049
# Rank 977: P-Value = 0.963, Critical Value = 0.049
# Rank 978: P-Value = 0.963, Critical Value = 0.049
# Rank 979: P-Value = 0.963, Critical Value = 0.049
# Rank 980: P-Value = 0.966, Critical Value = 0.049
# Rank 981: P-Value = 0.968, Critical Value = 0.049
# Rank 982: P-Value = 0.970, Critical Value = 0.049
# Rank 983: P-Value = 0.971, Critical Value = 0.049
# Rank 984: P-Value = 0.971, Critical Value = 0.049
# Rank 985: P-Value = 0.972, Critical Value = 0.049
# Rank 986: P-Value = 0.973, Critical Value = 0.049
# Rank 987: P-Value = 0.975, Critical Value = 0.049
# Rank 988: P-Value = 0.976, Critical Value = 0.049
# Rank 989: P-Value = 0.977, Critical Value = 0.049
# Rank 990: P-Value = 0.977, Critical Value = 0.050
# Rank 991: P-Value = 0.978, Critical Value = 0.050
# Rank 992: P-Value = 0.988, Critical Value = 0.050
# Rank 993: P-Value = 0.991, Critical Value = 0.050
# Rank 994: P-Value = 0.991, Critical Value = 0.050
# Rank 995: P-Value = 0.995, Critical Value = 0.050
# Rank 996: P-Value = 0.997, Critical Value = 0.050
# Rank 997: P-Value = 0.998, Critical Value = 0.050
# Rank 998: P-Value = 0.999, Critical Value = 0.050
# Rank 999: P-Value = 0.999, Critical Value = 0.050
# Rank 1000: P-Value = 0.999, Critical Value = 0.050
# New Criterion: P-Value <= None

# %% [markdown]
# Boferroni correction
# The simplest way to correct for Type I errors (false positives) in multiple comparisons is to divide
# alpha by the number of comparisons, known as the Bonferroni correction. This is a very conservative test that is typically used when the number of comparisons is relatively small and you want to avoid Type I errors.

# %%
# use the Bonferroni correction to address the multiple comparisons problem
num_comparisons = 2
corrected_alpha = p_values_lessthan05_proportion / num_comparisons

print(f"New Criterion: P-Value <= {corrected_alpha:.3f}")
# Out:
# New Criterion: P-Value <= 0.022

# %%
#re-run the above code using mean1 = 1 and mean2 = 2

import numpy as np
from scipy.stats import ttest_ind

# Parameters
sample_size = 100  # Size of each sample
num_simulations = 1000  # Number of simulations
mean1 = 1 # mean of sample 1 is 1
mean2 = 2 # mean of sample 2 is 2

# Initialize an empty list to store p-values
p_values = []

# Simulate t-tests
for _ in range(num_simulations):
    # Generate two random samples with equal means and standard deviations
    sample1 = np.random.normal(loc=mean1, scale=1, size=sample_size)
    sample2 = np.random.normal(loc=mean2, scale=1, size=sample_size)
    
    # Perform a t-test
    _, p_value = ttest_ind(sample1, sample2)
    
    # Append the p-value to the list
    p_values.append(p_value)


p_values_lessthan05_count = sum(i < 0.05 for i in p_values)
p_values_lessthan05_proportion = p_values_lessthan05_count / num_simulations
print(f"Proportion of p-values less than 0.05: {p_values_lessthan05_proportion:.3f}")


# use the Benjamini-Hochberg procedure to address the multiple comparisons problem

# STEP 1: Rank the individual p-values in ascending order, labeled i=1...n

# Rank the p-values in ascending order and assign labels as numbers
sorted_indices = np.argsort(p_values)  # Indices that would sort the p-values

# Create a dictionary to map ranks to p-values
ranked_p_values = {str(i): p_values[idx] for i, idx in enumerate(sorted_indices, start=1)}


# STEP 2: For each p-value, calculate its "critical value" as (i/n)Q, where i is the rank, n is the total number of tests, and Q is the false discovery rate (a percentage) that you choose (typically 0.05).

false_discovery_rate = 0.05
critical_values = [(i / num_simulations) * false_discovery_rate for i in range(1, num_simulations + 1)]

# Print the ranked p-values and their corresponding critical values
#for rank, (p_value, critical_value) in enumerate(zip(np.array(p_values)[sorted_indices], critical_values), start=1):
#    print(f"Rank {rank}: P-Value = {p_value:.3f}, Critical Value = {critical_value:.3f}")
    
# STEP 3: In your rank-ordered, original p-values, find the largest value that is smaller than its associated critical value; this p-value is the new criterion (i.e., reject for all cases for which p ≤ this value).

# Find the largest p-value that is smaller than its associated critical value
new_criterion = None
for p_value, critical_value in zip(np.array(p_values)[sorted_indices], critical_values):
    if p_value <= critical_value:
        new_criterion = p_value
    else:
        break
        
# Print the new criterion
print(f"Benjamini-Hochberg: New Criterion: P-Value <= {new_criterion:.3f}")

# use the Bonferroni correction to address the multiple comparisons problem
num_comparisons = 2
corrected_alpha = p_values_lessthan05_proportion / num_comparisons

print(f"Bonferroni correction: New Criterion: P-Value <= {corrected_alpha:.3f}")
# Out:
# Proportion of p-values less than 0.05: 1.000
# Benjamini-Hochberg: New Criterion: P-Value <= 0.001
# Bonferroni correction: New Criterion: P-Value <= 0.500

# %%
#re-run the above code using mean1 = 1 and mean2 = 5
#re-run the above code using mean1 = 1 and mean2 = 2

import numpy as np
from scipy.stats import ttest_ind

# Parameters
sample_size = 100  # Size of each sample
num_simulations = 1000  # Number of simulations
mean1 = 1 # mean of sample 1 is 1
mean2 = 5 # mean of sample 2 is 2

# Initialize an empty list to store p-values
p_values = []

# Simulate t-tests
for _ in range(num_simulations):
    # Generate two random samples with equal means and standard deviations
    sample1 = np.random.normal(loc=mean1, scale=1, size=sample_size)
    sample2 = np.random.normal(loc=mean2, scale=1, size=sample_size)
    
    # Perform a t-test
    _, p_value = ttest_ind(sample1, sample2)
    
    # Append the p-value to the list
    p_values.append(p_value)


p_values_lessthan05_count = sum(i < 0.05 for i in p_values)
p_values_lessthan05_proportion = p_values_lessthan05_count / num_simulations
print(f"Proportion of p-values less than 0.05: {p_values_lessthan05_proportion:.3f}")


# use the Benjamini-Hochberg procedure to address the multiple comparisons problem

# STEP 1: Rank the individual p-values in ascending order, labeled i=1...n

# Rank the p-values in ascending order and assign labels as numbers
sorted_indices = np.argsort(p_values)  # Indices that would sort the p-values

# Create a dictionary to map ranks to p-values
ranked_p_values = {str(i): p_values[idx] for i, idx in enumerate(sorted_indices, start=1)}


# STEP 2: For each p-value, calculate its "critical value" as (i/n)Q, where i is the rank, n is the total number of tests, and Q is the false discovery rate (a percentage) that you choose (typically 0.05).

false_discovery_rate = 0.05
critical_values = [(i / num_simulations) * false_discovery_rate for i in range(1, num_simulations + 1)]

# Print the ranked p-values and their corresponding critical values
#for rank, (p_value, critical_value) in enumerate(zip(np.array(p_values)[sorted_indices], critical_values), start=1):
#    print(f"Rank {rank}: P-Value = {p_value:.3f}, Critical Value = {critical_value:.3f}")
    
# STEP 3: In your rank-ordered, original p-values, find the largest value that is smaller than its associated critical value; this p-value is the new criterion (i.e., reject for all cases for which p ≤ this value).

# Find the largest p-value that is smaller than its associated critical value
new_criterion = None
for p_value, critical_value in zip(np.array(p_values)[sorted_indices], critical_values):
    if p_value <= critical_value:
        new_criterion = p_value
    else:
        break
        
# Print the new criterion
print(f"Benjamini-Hochberg: New Criterion: P-Value <= {new_criterion:.3f}")

# use the Bonferroni correction to address the multiple comparisons problem
num_comparisons = 2
corrected_alpha = p_values_lessthan05_proportion / num_comparisons

print(f"Bonferroni correction: New Criterion: P-Value <= {corrected_alpha:.3f}")
# Out:
# Proportion of p-values less than 0.05: 1.000
# Benjamini-Hochberg: New Criterion: P-Value <= 0.000
# Bonferroni correction: New Criterion: P-Value <= 0.500
